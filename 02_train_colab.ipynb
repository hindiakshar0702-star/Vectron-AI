# %% [markdown]
# <a href="https://colab.research.google.com/github/hindiakshar0702-star/Vectron-AI/blob/scaffold%2Finitial-training-pipeline/02_train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
